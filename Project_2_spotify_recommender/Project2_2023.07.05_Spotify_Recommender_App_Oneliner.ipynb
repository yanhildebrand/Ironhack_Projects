# %%
import spotify_recommender_app
spotify_recommender_app.song_recommender()
# Out:
# enter song and/or artist name: Till I collapse
# Song is not Present in the Top 100
# Recommending according to Spotify features
# The original track
#         <iframe
#             width="480"
#             height="180"
#             src="https://open.spotify.com/embed/track/4xkOaSrkexMciUUogZKVTS"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Is this the right track? Type 'yes' or 'no': yes
#         <iframe
#             width="480"
#             height="180"
#             src="https://open.spotify.com/embed/track/4b2Na0O43RaBt8h9THM2oq"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Would you like a further suggestion? Type 'yes' or 'no':
# yes
#         <iframe
#             width="480"
#             height="180"
#             src="https://open.spotify.com/embed/track/0NsigEyiIwuysCjeU9EhRU"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ()
